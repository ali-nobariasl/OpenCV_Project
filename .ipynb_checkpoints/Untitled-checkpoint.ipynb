# %%
import numpy as np
import cv2 as cv
import docx


documents =  docx.Document(r'C:\Users\Ronwell\Desktop\ali\document.docx')
all_params = documents.paragraphs

# %%
data = all_params[0].text

# %%
data
# Out:
# '[\'02/03/2017 TARIHLI RESMI YAHYA AKMAN, CUMHURBASKANLIGI HUKUMET SISTEMINDE IDARENIN DENETIM MEKANIZMALARININ INCELENMESI CALISTAY RAPORU, III. OTURUM, ANKARA,2017\',\n \'28/03/2013 TARIHLI VE 28601 MUKERRER SAYILI RESMI GAZETEDE\',\n \'29.06.2012 TARIH VE 28338 SAYILI RESMI GAZETEDE\',\n \'ABDURRAHMAN EREN, 6. YILINDA OMBUDSMANLIGIN DUNU BUGUNU YARINI SEMPOZYUMU “CUMHURBASKANLIGI HUKUMET SISTEMINDE KAMU DENETCILIGI KURUMUNUN ONEMI VE KAMU DENETCILIGI KURUMUNUN GELECEK HEDEFLERI” 242\',\n \'ACAR ORNEK, KAMU YONETIMI, MERAM YAYIN DAGITIM, ISTANBUL, 1991\',\n \'ACARAY, DENIZ, INSAN HAKLARI, POLIS AKADEMISI YAYINLARI, 3. BASKI, ANKARA, 2020. AKCALI, PINAR, (YARI) BASKANLIK SISTEMI VE TURKIYE, KALKEDON YAYINLARI, 2.BASKI, ISTANBUL, 2014\',\n \'AHMET ALKAN SIMSEK, KAMU DENETCILIGI KURUMU KANUNU YORUMU VE ILGILI MEVZUAT, ADALET YAYINEVI, 2013, ANKARA\',\n \'AHMET BULUT, HUKUMET SISTEMLERININ YONETSEL BASARI ACISINDAN INCELENMESI: CUMHURBASKANLIGI HUKUMET SISTEMINDEN BEKLENTILER, YAYINLAN
# ...

# %%
ali =[]
for i in data.split("'"):
    ali.append(i)
    print(i)
# Out:
# [
# 02/03/2017 TARIHLI RESMI YAHYA AKMAN, CUMHURBASKANLIGI HUKUMET SISTEMINDE IDARENIN DENETIM MEKANIZMALARININ INCELENMESI CALISTAY RAPORU, III. OTURUM, ANKARA,2017
# ,
#
# 28/03/2013 TARIHLI VE 28601 MUKERRER SAYILI RESMI GAZETEDE
# ,
#
# 29.06.2012 TARIH VE 28338 SAYILI RESMI GAZETEDE
# ,
#
# ABDURRAHMAN EREN, 6. YILINDA OMBUDSMANLIGIN DUNU BUGUNU YARINI SEMPOZYUMU “CUMHURBASKANLIGI HUKUMET SISTEMINDE KAMU DENETCILIGI KURUMUNUN ONEMI VE KAMU DENETCILIGI KURUMUNUN GELECEK HEDEFLERI” 242
# ,
#
# ACAR ORNEK, KAMU YONETIMI, MERAM YAYIN DAGITIM, ISTANBUL, 1991
# ,
#
# ACARAY, DENIZ, INSAN HAKLARI, POLIS AKADEMISI YAYINLARI, 3. BASKI, ANKARA, 2020. AKCALI, PINAR, (YARI) BASKANLIK SISTEMI VE TURKIYE, KALKEDON YAYINLARI, 2.BASKI, ISTANBUL, 2014
# ,
#
# AHMET ALKAN SIMSEK, KAMU DENETCILIGI KURUMU KANUNU YORUMU VE ILGILI MEVZUAT, ADALET YAYINEVI, 2013, ANKARA
# ,
#
# ...

# %%
blank = np.zeros((500,500,3), dtype='uint8')

my_text = "Hello world im back"
x = 25
y = 25
# Out:
# ['[',
#  '02/03/2017 TARIHLI RESMI YAHYA AKMAN, CUMHURBASKANLIGI HUKUMET SISTEMINDE IDARENIN DENETIM MEKANIZMALARININ INCELENMESI CALISTAY RAPORU, III. OTURUM, ANKARA,2017',
#  ',\n ',
#  '28/03/2013 TARIHLI VE 28601 MUKERRER SAYILI RESMI GAZETEDE',
#  ',\n ',
#  '29.06.2012 TARIH VE 28338 SAYILI RESMI GAZETEDE',
#  ',\n ',
#  'ABDURRAHMAN EREN, 6. YILINDA OMBUDSMANLIGIN DUNU BUGUNU YARINI SEMPOZYUMU “CUMHURBASKANLIGI HUKUMET SISTEMINDE KAMU DENETCILIGI KURUMUNUN ONEMI VE KAMU DENETCILIGI KURUMUNUN GELECEK HEDEFLERI” 242',
#  ',\n ',
#  'ACAR ORNEK, KAMU YONETIMI, MERAM YAYIN DAGITIM, ISTANBUL, 1991',
#  ',\n ',
#  'ACARAY, DENIZ, INSAN HAKLARI, POLIS AKADEMISI YAYINLARI, 3. BASKI, ANKARA, 2020. AKCALI, PINAR, (YARI) BASKANLIK SISTEMI VE TURKIYE, KALKEDON YAYINLARI, 2.BASKI, ISTANBUL, 2014',
#  ',\n ',
#  'AHMET ALKAN SIMSEK, KAMU DENETCILIGI KURUMU KANUNU YORUMU VE ILGILI MEVZUAT, ADALET YAYINEVI, 2013, ANKARA',
#  ',\n ',
# ...
